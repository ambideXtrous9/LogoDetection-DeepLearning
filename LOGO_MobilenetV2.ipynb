# %% [markdown]
# <a href="https://colab.research.google.com/github/SUSHOVAN95/LOGO-DETECTION-USING-CNN/blob/master/LOGO_MobilenetV2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# import the necessary packages
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.applications import MobileNetV2
from tensorflow.keras.layers import AveragePooling2D
from tensorflow.keras.layers import Dropout
from tensorflow.keras.layers import Flatten
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import Input
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import Adam,SGD
from tensorflow.keras.applications.mobilenet_v2 import preprocess_input
from tensorflow.keras.preprocessing.image import img_to_array
from tensorflow.keras.preprocessing.image import load_img
from tensorflow.keras.utils import to_categorical
from sklearn.preprocessing import LabelBinarizer
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report
from imutils import paths
import matplotlib.pyplot as plt
import numpy as np
import argparse
import os
import cv2
import tensorflow as tf
import tensorflow_datasets.public_api as tfds

# %%
_URL = 'http://image.ntua.gr/iva/datasets/flickr_logos/flickr_logos_27_dataset.tar.gz'
zip_dir = tf.keras.utils.get_file('/content/logo', origin=_URL, untar=True,extract=True)
# Out:
# Downloading data from http://image.ntua.gr/iva/datasets/flickr_logos/flickr_logos_27_dataset.tar.gz
# 101834752/101827904 [==============================] - 19s 0us/step

# %%
import tarfile

fname = '/content/logo.tar.gz'

if fname.endswith("tar.gz"):
    tar = tarfile.open(fname, "r:gz")
    tar.extractall()
    tar.close()

# %%
fname = '/content/flickr_logos_27_dataset/flickr_logos_27_dataset_images.tar.gz'

if fname.endswith("tar.gz"):
    tar = tarfile.open(fname, "r:gz")
    tar.extractall()
    tar.close()

# %%
src_dir = "flickr_logos_27_dataset_images"
dest = "LOGOS"

if not os.path.exists(dest):
    os.makedirs(dest)

# %%
import pandas as pd
from google.colab.patches import cv2_imshow

# %%
df = pd.read_csv("/content/flickr_logos_27_dataset/flickr_logos_27_dataset_training_set_annotation.txt", sep='\s+',header=None)

# %%
df
# Out:
#                    0       1  2    3    4    5    6
# 0      144503924.jpg  Adidas  1   38   12  234  142
# 1     2451569770.jpg  Adidas  1  242  208  413  331
# 2      390321909.jpg  Adidas  1   13    5   89   60
# 3     4761260517.jpg  Adidas  1   43  122  358  354
# 4     4763210295.jpg  Adidas  1   83   63  130   93
# ...              ...     ... ..  ...  ...  ...  ...
# 4531  2126991906.jpg   Yahoo  6   15    6  253   54
# 4532   217288720.jpg   Yahoo  6  136  161  304  222
# 4533  2472817996.jpg   Yahoo  6    2    4  499  106
# 4534  2514220918.jpg   Yahoo  6    1   69  342  157
# 4535   386891249.jpg   Yahoo  6  156   10  310   49
#
# [4536 rows x 7 columns]

# %%
dtdir = '/content/flickr_logos_27_dataset_images/'

# %%
im = df[0][0]

# %%
size = df.iloc[:,3:]

# %%
size
# Out:
#         3    4    5    6
# 0      38   12  234  142
# 1     242  208  413  331
# 2      13    5   89   60
# 3      43  122  358  354
# 4      83   63  130   93
# ...   ...  ...  ...  ...
# 4531   15    6  253   54
# 4532  136  161  304  222
# 4533    2    4  499  106
# 4534    1   69  342  157
# 4535  156   10  310   49
#
# [4536 rows x 4 columns]

# %%
img = os.path.join(dtdir,im)

# %%
size = size.values.tolist()

# %%
size[0][0],size[0][1],size[0][2],size[0][3]
# Out:
# (38, 12, 234, 142)

# %%
image = cv2.imread(img)
cv2_imshow(image)
image.shape
# Out:
# <PIL.Image.Image image mode=RGB size=280x210 at 0x7F83E0FFC940>
# (210, 280, 3)

# %%
image = cv2.imread(img)
image = image[size[0][1]:size[0][3],size[0][0]:size[0][2]]
cv2_imshow(image)
image.shape
# Out:
# <PIL.Image.Image image mode=RGB size=196x130 at 0x7F83E058CF98>
# (130, 196, 3)

# %%
X = df.iloc[:,0]
Y = df.iloc[:,1]

# %%
y = list(set(list(Y)))
y.sort()

# %%
for i in y:
    os.makedirs(os.path.join(dest,i))

# %%
for i in range(len(X)):
    try:
        destrain = os.path.join(dest,Y[i])
        savepath = os.path.join(destrain,X[i])
        img  = os.path.join(dtdir,X[i])
        image = cv2.imread(img)
        image = image[size[i][1]:size[i][3],size[i][0]:size[i][2]]
        image = cv2.resize(image,(224,224))
        cv2.imwrite(savepath,image)
    except:
        print('error')
        pass
# Out:
# error
# error
# error
# error
# error

# %%
train = ImageDataGenerator(
rescale = 1/255,
horizontal_flip=True,
vertical_flip=True,
shear_range=0.2,
zoom_range=0.2,
featurewise_center=True, # Set input mean to 0 over the dataset, feature-wise
featurewise_std_normalization=True, # Divide inputs by std of the dataset, feature-wise
rotation_range=40, # Degree range for random rotations
width_shift_range=0.2,
height_shift_range=0.2,
fill_mode='nearest',
validation_split=0.1)

# %%
imagePaths = list(paths.list_images(dest))

# %%
os.makedirs('preview')

# %%
img = load_img(imagePaths[800])  # this is a PIL image
x = img_to_array(img)  # this is a Numpy array with shape (3, 150, 150)
x = x.reshape((1,) + x.shape)  # this is a Numpy array with shape (1, 3, 150, 150)

# the .flow() command below generates batches of randomly transformed images
# and saves the results to the `preview/` directory
i = 0
for batch in train.flow(x, batch_size=1,
                          save_to_dir='preview', save_prefix='yh', save_format='jpeg'):
    i += 1
    if i > 20:
        break  # otherwise the generator would loop indefinitely
# Out:
# /usr/local/lib/python3.6/dist-packages/keras_preprocessing/image/image_data_generator.py:720: UserWarning: This ImageDataGenerator specifies `featurewise_center`, but it hasn't been fit on any training data. Fit it first by calling `.fit(numpy_data)`.
#   warnings.warn('This ImageDataGenerator specifies '
# /usr/local/lib/python3.6/dist-packages/keras_preprocessing/image/image_data_generator.py:728: UserWarning: This ImageDataGenerator specifies `featurewise_std_normalization`, but it hasn't been fit on any training data. Fit it first by calling `.fit(numpy_data)`.
#   warnings.warn('This ImageDataGenerator specifies '

# %%
image = cv2.imread(imagePaths[800])
cv2_imshow(image)
image.shape
# Out:
# <PIL.Image.Image image mode=RGB size=224x224 at 0x7F836C196BE0>
# (224, 224, 3)

# %%
import glob
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
# %matplotlib inline

images = []
for img_path in glob.glob('preview/*.jpeg'):
    images.append(mpimg.imread(img_path))

plt.figure(figsize=(20,10))
columns = 8
for i, image in enumerate(images):
    plt.subplot(len(images) / columns + 1, columns, i + 1)
    plt.imshow(image)

# %%
HEIGHT = 224
WIDTH = 224
INIT_LR = 1e-4
EPOCHS = 200 
BS = 16

# %%
trainset = train.flow_from_directory(dest,
target_size = (WIDTH,HEIGHT),
batch_size = BS,
shuffle=False,
seed=42,
color_mode='rgb',
class_mode='categorical')
# Out:
# Found 809 images belonging to 27 classes.

# %%
validset = train.flow_from_directory(dest,
target_size = (WIDTH,HEIGHT),
batch_size = BS,
shuffle=False,
seed=42,
color_mode='rgb',
class_mode='categorical',
subset = 'validation')
# Out:
# Found 80 images belonging to 27 classes.

# %%
imagePaths = list(paths.list_images(dest))

# %%
imagePaths[0]
# Out:
# 'LOGOS/Adidas/3005794070.jpg'

# %%
image = cv2.imread(imagePaths[0])
cv2_imshow(image)
image.shape
# Out:
# <PIL.Image.Image image mode=RGB size=224x224 at 0x7F83E02BC630>
# (224, 224, 3)

# %%
trainset.num_classes
# Out:
# 27

# %%
trainset.filenames

# %%
trainset.class_indices
# Out:
# {'Adidas': 0,
#  'Apple': 1,
#  'BMW': 2,
#  'Citroen': 3,
#  'Cocacola': 4,
#  'DHL': 5,
#  'Fedex': 6,
#  'Ferrari': 7,
#  'Ford': 8,
#  'Google': 9,
#  'HP': 10,
#  'Heineken': 11,
#  'Intel': 12,
#  'McDonalds': 13,
#  'Mini': 14,
#  'Nbc': 15,
#  'Nike': 16,
#  'Pepsi': 17,
#  'Porsche': 18,
#  'Puma': 19,
#  'RedBull': 20,
#  'Sprite': 21,
#  'Starbucks': 22,
#  'Texaco': 23,
#  'Unicef': 24,
#  'Vodafone': 25,
#  'Yahoo': 26}

# %%
# load the MobileNetV2 network, ensuring the head FC layer sets are
# left off
baseModel = MobileNetV2(weights="imagenet", include_top=False,input_tensor=Input(shape=(224, 224, 3)))

# construct the head of the model that will be placed on top of the
# the base model
headModel = baseModel.output
headModel = AveragePooling2D(pool_size=(7, 7))(headModel)
headModel = Flatten(name="flatten")(headModel)
headModel = Dense(128, activation="relu")(headModel)
headModel = Dropout(0.5)(headModel)
headModel = Dense(trainset.num_classes, activation="softmax")(headModel)
# place the head FC model on top of the base model (this will become
# the actual model we will train)
model = Model(inputs=baseModel.input, outputs=headModel)
# loop over all layers in the base model and freeze them so they will
# *not* be updated during the first training process
for layer in baseModel.layers:
	layer.trainable = False

# compile our model
print("[INFO] compiling model...")
opt = SGD(lr=INIT_LR, momentum = 0.9)
model.compile(loss="categorical_crossentropy", optimizer=opt,
	metrics=["accuracy"])
# train the head of the network
# Out:
# WARNING:tensorflow:`input_shape` is undefined or non-square, or `rows` is not in [96, 128, 160, 192, 224]. Weights for input shape (224, 224) will be loaded as the default.
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/mobilenet_v2/mobilenet_v2_weights_tf_dim_ordering_tf_kernels_1.0_224_no_top.h5
# 9412608/9406464 [==============================] - 0s 0us/step
# [INFO] compiling model...

# %%
totalTrain = len(list(paths.list_images(dest)))
totalTrain
# Out:
# 809

# %%
H = model.fit_generator(
	trainset,
  validation_data = validset,
	epochs=EPOCHS)
# Out:
# /usr/local/lib/python3.6/dist-packages/keras_preprocessing/image/image_data_generator.py:720: UserWarning: This ImageDataGenerator specifies `featurewise_center`, but it hasn't been fit on any training data. Fit it first by calling `.fit(numpy_data)`.
#   warnings.warn('This ImageDataGenerator specifies '
# /usr/local/lib/python3.6/dist-packages/keras_preprocessing/image/image_data_generator.py:728: UserWarning: This ImageDataGenerator specifies `featurewise_std_normalization`, but it hasn't been fit on any training data. Fit it first by calling `.fit(numpy_data)`.
#   warnings.warn('This ImageDataGenerator specifies '
# Epoch 1/200
# 51/51 [==============================] - 10s 192ms/step - loss: 0.5493 - accuracy: 0.8554 - val_loss: 0.1881 - val_accuracy: 0.9875
# Epoch 2/200
# 51/51 [==============================] - 10s 193ms/step - loss: 0.5433 - accuracy: 0.8591 - val_loss: 0.2648 - val_accuracy: 0.9375
# Epoch 3/200
# 51/51 [==============================] - 10s 191ms/step - loss: 0.5512 - accuracy: 0.8517 - val_loss: 0.2149 - val_accuracy: 0.9750
# Epoch 4/200
# 51/51 [==============================] - 10s 194ms/step - loss: 0.5322 - accuracy: 0.8628 - val_loss: 0.1907 - val_accuracy: 0.9750
# Epoch 5/200
# 51/51 [==============================] - 10s 191ms/step - loss: 0.5994 - accuracy: 0.8195 - val_loss: 0.1835 - val_accuracy: 0.9875
# Epoch 6/200
# 51/51 [==============================] - 10s 196ms/step - loss: 0.5717 - accuracy: 0.8640 - val_loss: 0.2266 - val_accuracy: 0.9625
# Epoch 7/200
# 51/51 [==============================] - 10s 193ms/step - loss: 0.5236 - accuracy: 0.8677 - val_loss: 0.1868 - val_accuracy: 0.9625
# Epoch 8/200
# 51/51 [==============================] - 10s 194ms/step - loss: 0.5401 - accuracy: 0.8591 - val_loss: 0.2033 - val_accuracy: 1.0000
# Epoch 9/200
# 51/51 [==============================] - 10s 192ms/step - loss: 0.5466 - accuracy: 0.8430 - val_loss: 0.2810 - val_accuracy: 0.9125
# Epoch 10/200
# 51/51 [==============================] - 10s 191ms/step - loss: 0.5306 - accuracy: 0.8690 - val_loss: 0.2036 - val_accuracy: 0.9750
# Epoch 11/200
# 51/51 [==============================] - 10s 192ms/step - loss: 0.4869 - accuracy: 0.8702 - val_loss: 0.2519 - val_accuracy: 0.9500
# Epoch 12/200
# 51/51 [==============================] - 10s 193ms/step - loss: 0.5609 - accuracy: 0.8467 - val_loss: 0.2269 - val_accuracy: 0.9625
# Epoch 13/200
# 51/51 [==============================] - 10s 192ms/step - loss: 0.5103 - accuracy: 0.8591 - val_loss: 0.1972 - val_accuracy: 0.9875
# Epoch 14/200
# 51/51 [==============================] - 10s 191ms/step - loss: 0.5100 - accuracy: 0.8554 - val_loss: 0.2120 - val_accuracy: 0.9750
# Epoch 15/200
# 51/51 [==============================] - 10s 192ms/step - loss: 0.4953 - accuracy: 0.8764 - val_loss: 0.1932 - val_accuracy: 0.9750
# Epoch 16/200
# 51/51 [==============================] - 10s 191ms/step - loss: 0.5486 - accuracy: 0.8467 - val_loss: 0.1887 - val_accuracy: 0.9750
# Epoch 17/200
# 51/51 [==============================] - 10s 191ms/step - loss: 0.5197 - accuracy: 0.8504 - val_loss: 0.1771 - val_accuracy: 0.9625
# Epoch 18/200
# 51/51 [==============================] - 10s 192ms/step - loss: 0.5429 - accuracy: 0.8480 - val_loss: 0.2134 - val_accuracy: 0.9625
# Epoch 19/200
# 51/51 [==============================] - 10s 191ms/step - loss: 0.4945 - accuracy: 0.8826 - val_loss: 0.2068 - val_accuracy: 0.9875
# Epoch 20/200
# 51/51 [==============================] - 10s 194ms/step - loss: 0.4688 - accuracy: 0.8850 - val_loss: 0.1942 - val_accuracy: 0.9625
# Epoch 21/200
# 51/51 [==============================] - 10s 192ms/step - loss: 0.4847 - accuracy: 0.8714 - val_loss: 0.2371 - val_accuracy: 0.9250
# Epoch 22/200
# 51/51 [==============================] - 10s 192ms/step - loss: 0.4721 - accuracy: 0.8863 - val_loss: 0.2468 - val_accuracy: 0.9250
# Epoch 23/200
# 51/51 [==============================] - 10s 193ms/step - loss: 0.5055 - accuracy: 0.8677 - val_loss: 0.1569 - val_accuracy: 0.9875
# Epoch 24/200
# 51/51 [==============================] - 10s 192ms/step - loss: 0.5167 - accuracy: 0.8727 - val_loss: 0.2358 - val_accuracy: 0.9500
# Epoch 25/200
# 51/51 [==============================] - 10s 192ms/step - loss: 0.4691 - accuracy: 0.8702 - val_loss: 0.2040 - val_accuracy: 0.9625
# Epoch 26/200
# 51/51 [==============================] - 10s 192ms/step - loss: 0.4763 - accuracy: 0.8727 - val_loss: 0.2222 - val_accuracy: 0.9500
# Epoch 27/200
# 51/51 [==============================] - 10s 192ms/step - loss: 0.4766 - accuracy: 0.8752 - val_loss: 0.2155 - val_accuracy: 0.9625
# Epoch 28/200
# 51/51 [==============================] - 10s 195ms/step - loss: 0.4977 - accuracy: 0.8752 - val_loss: 0.2329 - val_accuracy: 0.9625
# Epoch 29/200
# 51/51 [==============================] - 10s 191ms/step - loss: 0.4871 - accuracy: 0.8578 - val_loss: 0.2219 - val_accuracy: 0.9625
# Epoch 30/200
# 51/51 [==============================] - 10s 191ms/step - loss: 0.4772 - accuracy: 0.8739 - val_loss: 0.1649 - val_accuracy: 0.9750
# Epoch 31/200
# 51/51 [==============================] - 10s 192ms/step - loss: 0.4977 - accuracy: 0.8690 - val_loss: 0.1926 - val_accuracy: 0.9750
# Epoch 32/200
# 51/51 [==============================] - 10s 192ms/step - loss: 0.5139 - accuracy: 0.8752 - val_loss: 0.1780 - val_accuracy: 0.9625
# Epoch 33/200
# 51/51 [==============================] - 10s 191ms/step - loss: 0.4594 - accuracy: 0.8727 - val_loss: 0.1941 - val_accuracy: 0.9500
# Epoch 34/200
# 51/51 [==============================] - 10s 192ms/step - loss: 0.5278 - accuracy: 0.8541 - val_loss: 0.2046 - val_accuracy: 0.9750
# Epoch 35/200
# 51/51 [==============================] - 10s 192ms/step - loss: 0.4640 - accuracy: 0.8752 - val_loss: 0.1910 - val_accuracy: 0.9750
# Epoch 36/200
# 51/51 [==============================] - 10s 194ms/step - loss: 0.5120 - accuracy: 0.8616 - val_loss: 0.1689 - val_accuracy: 0.9750
# Epoch 37/200
# 51/51 [==============================] - 10s 195ms/step - loss: 0.4775 - accuracy: 0.8714 - val_loss: 0.1660 - val_accuracy: 1.0000
# Epoch 38/200
# 51/51 [==============================] - 10s 196ms/step - loss: 0.4505 - accuracy: 0.8801 - val_loss: 0.1519 - val_accuracy: 0.9875
# Epoch 39/200
# 51/51 [==============================] - 10s 192ms/step - loss: 0.
200
# 51/51 [==============================] - 10s 192ms/step - loss: 0.3739 - accuracy: 0.8999 - val_loss: 0.1289 - val_accuracy: 0.9875
# Epoch 159/200
# 51/51 [==============================] - 10s 191ms/step - loss: 0.3630 - accuracy: 0.9048 - val_loss: 0.1241 - val_accuracy: 0.9750
# Epoch 160/200
# 51/51 [==============================] - 10s 194ms/step - loss: 0.3313 - accuracy: 0.9184 - val_loss: 0.1135 - val_accuracy: 0.9875
# Epoch 161/200
# 51/51 [==============================] - 10s 193ms/step - loss: 0.3553 - accuracy: 0.9172 - val_loss: 0.1198 - val_accuracy: 0.9750
# Epoch 162/200
# 51/51 [==============================] - 10s 195ms/step - loss: 0.3417 - accuracy: 0.9172 - val_loss: 0.1132 - val_accuracy: 1.0000
# Epoch 163/200
# 51/51 [==============================] - 10s 191ms/step - loss: 0.3263 - accuracy: 0.9159 - val_loss: 0.1285 - val_accuracy: 0.9875
# Epoch 164/200
# 51/51 [==============================] - 10s 193ms/step - loss: 0.3546 - accuracy: 0.9122 - val_loss: 0.1146 - val_accuracy: 0.9875
# Epoch 165/200
# 51/51 [==============================] - 10s 193ms/step - loss: 0.3295 - accuracy: 0.9197 - val_loss: 0.1015 - val_accuracy: 0.9875
# Epoch 166/200
# 51/51 [==============================] - 10s 191ms/step - loss: 0.3443 - accuracy: 0.9061 - val_loss: 0.1054 - val_accuracy: 0.9875
# Epoch 167/200
# 51/51 [==============================] - 10s 191ms/step - loss: 0.3603 - accuracy: 0.9085 - val_loss: 0.0954 - val_accuracy: 1.0000
# Epoch 168/200
# 51/51 [==============================] - 10s 191ms/step - loss: 0.3171 - accuracy: 0.9122 - val_loss: 0.1365 - val_accuracy: 0.9875
# Epoch 169/200
# 51/51 [==============================] - 10s 191ms/step - loss: 0.3302 - accuracy: 0.9085 - val_loss: 0.1268 - val_accuracy: 0.9750
# Epoch 170/200
# 51/51 [==============================] - 10s 191ms/step - loss: 0.3335 - accuracy: 0.9110 - val_loss: 0.0918 - val_accuracy: 1.0000
# Epoch 171/200
# 51/51 [==============================] - 10s 191ms/step - loss: 0.3258 - accuracy: 0.9098 - val_loss: 0.1135 - val_accuracy: 0.9875
# Epoch 172/200
# 51/51 [==============================] - 10s 192ms/step - loss: 0.3514 - accuracy: 0.9135 - val_loss: 0.0924 - val_accuracy: 1.0000
# Epoch 173/200
# 51/51 [==============================] - 10s 194ms/step - loss: 0.3480 - accuracy: 0.9048 - val_loss: 0.0931 - val_accuracy: 0.9750
# Epoch 174/200
# 51/51 [==============================] - 10s 191ms/step - loss: 0.3709 - accuracy: 0.8986 - val_loss: 0.1439 - val_accuracy: 0.9750
# Epoch 175/200
# 51/51 [==============================] - 10s 190ms/step - loss: 0.3578 - accuracy: 0.9036 - val_loss: 0.1067 - val_accuracy: 1.0000
# Epoch 176/200
# 51/51 [==============================] - 10s 191ms/step - loss: 0.3343 - accuracy: 0.9036 - val_loss: 0.1175 - val_accuracy: 0.9750
# Epoch 177/200
# 51/51 [==============================] - 10s 191ms/step - loss: 0.3187 - accuracy: 0.9061 - val_loss: 0.1239 - val_accuracy: 1.0000
# Epoch 178/200
# 51/51 [==============================] - 10s 192ms/step - loss: 0.3556 - accuracy: 0.9011 - val_loss: 0.0973 - val_accuracy: 1.0000
# Epoch 179/200
# 51/51 [==============================] - 10s 192ms/step - loss: 0.3101 - accuracy: 0.9271 - val_loss: 0.0850 - val_accuracy: 1.0000
# Epoch 180/200
# 51/51 [==============================] - 10s 192ms/step - loss: 0.3419 - accuracy: 0.9184 - val_loss: 0.0813 - val_accuracy: 1.0000
# Epoch 181/200
# 51/51 [==============================] - 10s 194ms/step - loss: 0.3290 - accuracy: 0.9098 - val_loss: 0.1038 - val_accuracy: 0.9875
# Epoch 182/200
# 51/51 [==============================] - 10s 193ms/step - loss: 0.3124 - accuracy: 0.9197 - val_loss: 0.1246 - val_accuracy: 0.9750
# Epoch 183/200
# 51/51 [==============================] - 10s 191ms/step - loss: 0.3457 - accuracy: 0.9073 - val_loss: 0.1229 - val_accuracy: 0.9750
# Epoch 184/200
# 51/51 [==============================] - 10s 191ms/step - loss: 0.3116 - accuracy: 0.9221 - val_loss: 0.1147 - val_accuracy: 0.9875
# Epoch 185/200
# 51/51 [==============================] - 10s 191ms/step - loss: 0.3273 - accuracy: 0.9110 - val_loss: 0.1149 - val_accuracy: 0.9875
# Epoch 186/200
# 51/51 [==============================] - 10s 191ms/step - loss: 0.3055 - accuracy: 0.9147 - val_loss: 0.1390 - val_accuracy: 0.9625
# Epoch 187/200
# 51/51 [==============================] - 10s 191ms/step - loss: 0.3349 - accuracy: 0.9122 - val_loss: 0.1054 - val_accuracy: 0.9875
# Epoch 188/200
# 51/51 [==============================] - 10s 193ms/step - loss: 0.3065 - accuracy: 0.9197 - val_loss: 0.0798 - val_accuracy: 1.0000
# Epoch 189/200
# 51/51 [==============================] - 10s 195ms/step - loss: 0.3180 - accuracy: 0.9184 - val_loss: 0.1586 - val_accuracy: 0.9625
# Epoch 190/200
# 51/51 [==============================] - 10s 191ms/step - loss: 0.3087 - accuracy: 0.9197 - val_loss: 0.1389 - val_accuracy: 0.9750
# Epoch 191/200
# 51/51 [==============================] - 10s 194ms/step - loss: 0.3511 - accuracy: 0.9011 - val_loss: 0.0886 - val_accuracy: 0.9875
# Epoch 192/200
# 51/51 [==============================] - 10s 193ms/step - loss: 0.2933 - accuracy: 0.9246 - val_loss: 0.1269 - val_accuracy: 0.9875
# Epoch 193/200
# 51/51 [==============================] - 10s 196ms/step - loss: 0.3389 - accuracy: 0.9073 - val_loss: 0.1386 - val_accuracy: 0.9625
# Epoch 194/200
# 51/51 [==============================] - 10s 192ms/step - loss: 0.2943 - accuracy: 0.9258 - val_loss: 0.1034 - val_accuracy: 0.9875
# Epoch 195/200
# 51/51 [==============================] - 10s 193ms/step - loss: 0.3154 - accuracy: 0.9147 - val_loss: 0.1051 - val_accuracy: 1.0000
# Epoch 196/200
# 51/51 [==============================] - 10s 193ms/step - loss: 0.3336 - accuracy: 0.9197 - val_loss: 0.0842 - val_accuracy: 0.9875
# Epoch 197/200
# 51/51 [==============================] - 10s 194ms/step - loss: 0.3517 - accuracy: 0.9098 - val_loss: 0.0610 - val_accuracy: 1.0000
# Epoch 198/200
# 51/51 [==============================] - 10s 193ms/step - loss: 0.2903 - accuracy: 0.9209 - val_loss: 0.1089 - val_accuracy: 0.9875
# Epoch 199/200
# 51/51 [==============================] - 10s 192ms/step - loss: 0.3251 - accuracy: 0.9122 - val_loss: 0.1295 - val_accuracy: 0.9875
# Epoch 200/200
# 51/51 [==============================] - 10s 192ms/step - loss: 0.2984 - accuracy: 0.9147 - val_loss: 0.0813 - val_accuracy: 1.0000

# %%
# plot the training loss and accuracy
N = EPOCHS
plt.style.use("ggplot")
plt.figure()
plt.plot(np.arange(0, N), H.history["loss"], label="train_loss")
plt.plot(np.arange(0, N), H.history["val_loss"], label="val_loss")
plt.title("Training Loss and Accuracy")
plt.xlabel("Epoch #")
plt.ylabel("Loss/Accuracy")
plt.legend(loc="lower left")
plt.show()
plt.savefig('graph.png')

# %%
N = EPOCHS
plt.style.use("ggplot")
plt.figure()
plt.plot(np.arange(0, N), H.history["accuracy"], label="train_acc")
plt.plot(np.arange(0, N), H.history["val_accuracy"], label="val_acc")
plt.title(" Accuracy")
plt.xlabel("Epoch #")
plt.ylabel("Accuracy")
plt.legend(loc="lower left")
plt.show()

# %%
# reset the testing generator and then use our trained model to
# make predictions on the data
print("[INFO] evaluating after fine-tuning network...")
validset.reset()
predIdxs = model.predict(x=validset)
predIdxs = np.argmax(predIdxs, axis=1)
print(classification_report(validset.classes, predIdxs,
	target_names=validset.class_indices.keys()))
# serialize the model to disk
print("[INFO] serializing network...")
model.save('logo.model', save_format="h5")
# Out:
# [INFO] evaluating after fine-tuning network...
# /usr/local/lib/python3.6/dist-packages/keras_preprocessing/image/image_data_generator.py:720: UserWarning: This ImageDataGenerator specifies `featurewise_center`, but it hasn't been fit on any training data. Fit it first by calling `.fit(numpy_data)`.
#   warnings.warn('This ImageDataGenerator specifies '
# /usr/local/lib/python3.6/dist-packages/keras_preprocessing/image/image_data_generator.py:728: UserWarning: This ImageDataGenerator specifies `featurewise_std_normalization`, but it hasn't been fit on any training data. Fit it first by calling `.fit(numpy_data)`.
#   warnings.warn('This ImageDataGenerator specifies '
#               precision    recall  f1-score   support
#
#       Adidas       1.00      1.00      1.00         3
#        Apple       1.00      1.00      1.00         3
#          BMW       1.00      1.00      1.00         3
#      Citroen       1.00      1.00      1.00         3
#     Cocacola       1.00      1.00      1.00         3
#          DHL       1.00      1.00      1.00         3
#        Fedex       1.00      1.00      1.00         3
#      Ferrari       1.00      1.00      1.00         3
#         Ford       1.00      1.00      1.00         3
#       Google       1.00      1.00      1.00         3
#           HP       1.00      1.00      1.00         3
#     Heineken       1.00      0.67      0.80         3
#        Intel       1.00      1.00      1.00         3
#    McDonalds       1.00      1.00      1.00         3
#         Mini       1.00      1.00      1.00         3
#          Nbc       1.00      1.00      1.00         3
#         Nike       1.00      1.00      1.00         3
#        Pepsi       1.00      1.00      1.00         3
#      Porsche       1.00      1.00      1.00         3
#         Puma       1.00      1.00      1.00         3
#      RedBull       1.00      1.00      1.00         2
#       Sprite       1.00      1.00      1.00         3
#    Starbucks       1.00      1.00      1.00         3
#       Texaco       1.00      1.00      1.00         3
#       Unicef       0.75      1.00      0.86         3
#     Vodafone       1.00      1.00      1.00         3
#        Yahoo       1.00      1.00      1.00         3
#
#     accuracy                           0.99        80
#    macro avg       0.99      0.99      0.99        80
# weighted avg       0.99      0.99      0.99        80
#
# [INFO] serializing network...
